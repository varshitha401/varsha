# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitha401/varsha/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
conversation_data={
    "hello":"Hi there! how can i help you today?",
    "hi":"hello! how are you?",
    "how are you":"i'm just a bot,but i'm doing great! how about you?",
    "what is ai":"ai stands for artificial intelligence,which enables machines to perform the task",
    "what is deep learning":"deep learning is a subset of ai that uses neural netwok",
    "bye":"Goodbye! have a nice day!",
    "thankyou":"you're welcome! happy to help",
}

# %%
def sample_chat(user_input, chat_history=[]):
    user_input_lower = user_input.lower()
    response = None

    for key in conversation_data:
        if key in user_input_lower:
            response = conversation_data[key]
            break

    if not response:
        response = "sorry, i don't understand that, can you ask something else?"

    chat_history.append(("you", user_input))
    chat_history.append(("bot", response))

    return response, chat_history

# %%
print("welcome to mini Conversational AI")
print("Type 'exit' or 'quit' to end the chat.\n")

chat_history = []

while True:
  user_input = input("you:")

  if user_input.lower() in ["exit","quit"]:
    print("chat ended.Goodbye!")
    break

    bot_response, chat_history = sample_chat(user_input,chat_history)
    print("bot:",bot_response)
# Out:
# welcome to mini Conversational AI
# Type 'exit' or 'quit' to end the chat.

# %%
print("\n==== full chat_history ====")
for speaker,message in chat_history:
  print(f"{speaker}:{message}")

  Useful for debugging or showing what happened in the session.
